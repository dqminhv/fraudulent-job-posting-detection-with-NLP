# %%
#install required package
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\dqmin\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\dqmin\anaconda3\lib\site-packages (from selenium) (0.10.3)
# Requirement already satisfied: trio~=0.17 in c:\users\dqmin\anaconda3\lib\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\dqmin\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\dqmin\anaconda3\lib\site-packages (from selenium) (2023.5.7)
# Requirement already satisfied: sortedcontainers in c:\users\dqmin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\dqmin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sniffio in c:\users\dqmin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\dqmin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.2)
# Requirement already satisfied: idna in c:\users\dqmin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\dqmin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\dqmin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\dqmin\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\dqmin\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\dqmin\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\dqmin\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# import required packages
from selenium import webdriver
import time

import pandas as pd

# %%
driver = webdriver.Chrome('C:\chromedriver_win32\chromedriver.exe')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\selenium\webdriver\common\driver_finder.py:42, in DriverFinder.get_path(service, options)
#      41 try:
# ---> 42     path = SeleniumManager().driver_location(options) if path is None else path
#      43 except Exception as err:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\common\selenium_manager.py:74, in SeleniumManager.driver_location(self, options)
#      72 logger.debug("Applicable driver not found; attempting to install with Selenium Manager (Beta)")
# ---> 74 browser = options.capabilities["browserName"]
#      76 args = [str(self.get_binary()), "--browser", browser, "--output", "json"]
#
# AttributeError: 'str' object has no attribute 'capabilities'
#
# During handling of the above exception, another exception occurred:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 driver = webdriver.Chrome('C:\chromedriver_win32\chromedriver.exe')
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 self.options = options if options else Options()
#      45 self.keep_alive = keep_alive
# ---> 47 self.service.path = DriverFinder.get_path(self.service, self.options)
#      49 super().__init__(
#      50     DesiredCapabilities.CHROME["browserName"],
#      51     "goog",
#    (...)
#      54     self.keep_alive,
#      55 )
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\common\driver_finder.py:44, in DriverFinder.get_path(service, options)
#      42     path = SeleniumManager().driver_location(options) if path is None else path
#      43 except Exception as err:
# ---> 44     raise NoSuchDriverException(f"Unable to obtain {service.path} using Selenium Manager; {err}")
#      46 if path is None or not Path(path).is_file():
#      47     raise NoSuchDriverException(f"Unable to locate or obtain {service.path}")
#
# NoSuchDriverException: Message: Unable to obtain chromedriver using Selenium Manager; 'str' object has no attribute 'capabilities'; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location
